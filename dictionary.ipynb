# %% [raw]
# Dictionary
#
# -it is mapping data structure
# -it collects elements hacing 'key ' 'value'pair separated by commas(,)
# encosed by curley brackets({})
#
# -it use dict() method for initialization

# %%
#dictionary initialization or empty dictionary 
abc = {}
print(abc,type(abc))

xyz = dict()
print(xyz,type())
