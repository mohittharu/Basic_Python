# %% [markdown]
# # Data Types

# %%
# str
X = "Hello World"

# int
y = 20 

# float
x = 20

# complex 
a = 1j

#  list
b = ["Apple", "Ball", "Cat"]

# tuple
c = {"Ram", "Shyam"}

# dict
d = {"name": "Mohit", "Age": "20"}

# %%
print(X , y, x, a, b, c, d)
# Out:
# Hello World 20 20 1j ['Apple', 'Ball', 'Cat'] {'Ram', 'Shyam'} {'name': 'Mohit', 'Age': '20'}
