# %%
#conditional statements
if 
if-else
if-elif  ladder

# %%
#wite a program to check whether the number is odd or even 

num=int(input('Enter the number:'))

if(num%2==0):
    print('the nbr is even..')

else:
    print()
