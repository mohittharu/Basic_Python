# %%
#input methid always accept value as string 

salary = int(input('Enter your salary:'))

print(salary, type(salary))
bonus= 100
final_salary = salary + bonus
final_salary
# Out:
# Enter your salary: 2000
# 2000 <class 'int'>
# 2100

# %%
#implict type conversion

a= 10
b= 5
print(type(a),type(b))

c=a/b
print(c    ,type(c))
# Out:
# <class 'int'> <class 'int'>
# 2.0 <class 'float'>

# %%
text='My name is Mohit Tharu.'

text_split = text.split()
print(text_split,type(text_split))
# Out:
# ['My', 'name', 'is', 'Mohit', 'Tharu.'] <class 'list'>

# %%
 #Explict type conversion 
#1. int

a=int(5)
print(a,type(a))
# Out:
# 5 <class 'int'>

# %%
b= 5.5 
print(b,type(b))

b=int(b)         # yeha mailey float value lai int ma change garey 
print(b,type(b))
# Out:
# 5.5 <class 'float'>
# 5 <class 'int'>

# %%
c='5.5'
print(c,type(c))

c=int(c)
print(c,type(c))
# Out:
# 5.5 <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 4
#       1 c='5.5'
#       2 print(c,type(c))
# ----> 4 c=int(c)
#       5 print(c,type(c))
#
# ValueError: invalid literal for int() with base 10: '5.5'

# %%
#2. float 

m = float(3.2)
print(m ,type(m))
# Out:
# 3.2 <class 'float'>

# %%
n = float(3.2)
print(n,type(n))
n=int(n)
print(n,type(n))
# Out:
# 3.2 <class 'float'>
# 3 <class 'int'>

# %%
#3. str()

abc= str('Mohit')
print(abc)
print(abc,type(abc))
# Out:
# Mohit
# Mohit <class 'str'>

# %%
list_book=['phy','bio','math']
list_book
# Out:
# ['phy', 'bio', 'math']

# %%
list_book.append('che')     #list ma add garna .append hunxa 
list_book
# Out:
# ['phy', 'bio', 'math', 'che']

# %%
tuple_book=('phy','bio','math')
tuple_book
# Out:
# ('phy', 'bio', 'math')

# %%
tuple_book.append('pop')
tuple_book
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 tuple_book.append('pop')
#       2 tuple_book
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
a =list(tuple_book)
a         #no a.    yesley accept gardaina
# Out:
# ['phy', 'bio', 'math']

# %%
a.append('pop')

# %%
a
# Out:
# ['phy', 'bio', 'math', 'pop', 'pop']

# %%
list_num= [2,3,4,1,5,6,8,20,50]
list_num
# Out:
# [2, 3, 4, 1, 5, 6, 8, 20, 50]

# %%
set(list_num)
# Out:
# {1, 2, 3, 4, 5, 6, 8, 20, 50}
