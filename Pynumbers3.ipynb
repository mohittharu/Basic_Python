# %% [markdown]
# # Py Numbers
# int
# float
# complex

# %%
x = 1     #int


y = 1.2   # float 


z = 1j    # complex

# %%
print(x,y,z)
# Out:
# 1 1.2 1j

# %%
# Boolean values

print(10>9)
print(10==0)

print(bool("hello"))
print(bool(15))

# function
def myfunc() :
    return True

if myfunc() :
    print("Yes")

else:
    print("No")
# Out:
# True
# False
# True
# True
# Yes
