# %%
student = {
    

    "Name" : "Mohit",
    "gpa" : "B+",
    "standard" : "10th",
}
print(type(student))
print(student)
# Out:
# <class 'dict'>
# {'Name': 'Mohit', 'gpa': 'B+', 'standard': '10th'}

# %%
['Mohit','Tharu']
print([0])
# Out:
# [0]

# %%
marks = [1.2,3.5,6.7,8.9]
print(marks)
print(type(marks))
print(marks[2])
print(marks[0])
# Out:
# [1.2, 3.5, 6.7, 8.9]
# <class 'list'>
# 6.7
# 1.2
