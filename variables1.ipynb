# %% [markdown]
# # Variables
# variables are containers for storing data values

# %%
x = 5
y = 'Mohit Tharu'

print(x)
print(y)
print(x, y)
# Out:
# 5
# Mohit Tharu
# 5 Mohit Tharu

# %%
# Global variable : outside the function 
x = 'Mohit'

def myfunc():    # function define 
    print("My Name  is " + x)
myfunc()  # calling function
# Out:
# My Name  is Mohit
